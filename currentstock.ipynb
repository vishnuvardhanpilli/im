# %%
import pandas as pd
from datetime import datetime, timedelta
import ast

# --- Configuration Constants ---
# The maximum stock level for each product after a restock.
MAX_STOCK = 1000
# The day of the month when restocking occurs.
RESTOCK_DAY = 5
# The name of the input CSV file.
CSV_FILE_PATH = '10000.csv'

# %%
import pandas as pd
import ast
from datetime import datetime, timedelta

# Constants
CSV_FILE_PATH = "bills.csv"
MAX_STOCK = 100
RESTOCK_DAY = 5


def load_and_preprocess_data(file_path):
    """
    Load and preprocess bill data from CSV file.
    
    Args:
        file_path (str): Path to the CSV file
        
    Returns:
        pd.DataFrame: Preprocessed transaction data
    """
    try:
        # Load CSV with datetime parsing
        df = pd.read_csv(file_path, parse_dates=['Date_Time'])
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return pd.DataFrame()
    except Exception as e:
        print(f"Error loading file: {e}")
        return pd.DataFrame()

    # Columns containing string representations of lists
    list_columns = ['Product_IDs', 'Quantities', 'Products_With_Brands']

    # Convert string lists to actual lists
    for col in list_columns:
        df[col] = df[col].apply(ast.literal_eval)

    # Explode lists to create one row per item
    df_exploded = df.explode(list_columns).reset_index(drop=True)

    # Rename columns for clarity
    df_exploded.rename(columns={
        'Product_IDs': 'Product_ID',
        'Quantities': 'Quantity',
        'Products_With_Brands': 'Product_Name'
    }, inplace=True)

    # Convert quantity to numeric
    df_exploded['Quantity'] = pd.to_numeric(df_exploded['Quantity'])

    # Sort by date and time
    df_exploded.sort_values('Date_Time', inplace=True)
    df_exploded.reset_index(drop=True, inplace=True)

    return df_exploded


def simulate_inventory(transactions_df, target_date, max_stock):
    """
    Simulate inventory levels up to target date.
    
    Args:
        transactions_df (pd.DataFrame): Transaction data
        target_date (datetime): Date to calculate stock for
        max_stock (int): Maximum stock level
        
    Returns:
        tuple: (previous_stock, current_stock, product_names)
    """
    if transactions_df.empty:
        return {}, {}, {}

    # Get all unique products
    all_products = transactions_df['Product_ID'].unique()
    
    # Create product name mapping
    product_names = (transactions_df.drop_duplicates('Product_ID')
                    .set_index('Product_ID')['Product_Name'].to_dict())

    # Initialize stock levels
    stock = {pid: max_stock for pid in all_products}

    # Start from first day of month containing first transaction
    first_date = transactions_df['Date_Time'].min().date()
    start_date = first_date.replace(day=1)

    # Simulate day by day
    current_date = start_date
    previous_stock = None
    
    while current_date <= target_date.date():
        # Restock on the 5th of each month
        if current_date.day == RESTOCK_DAY:
            stock = {pid: max_stock for pid in all_products}

        # Capture stock at start of target date
        if current_date == target_date.date():
            previous_stock = stock.copy()

        # Process daily sales
        daily_sales = transactions_df[transactions_df['Date_Time'].dt.date == current_date]
        for _, sale in daily_sales.iterrows():
            stock[sale['Product_ID']] -= sale['Quantity']

        current_date += timedelta(days=1)

    current_stock = stock
    
    return previous_stock, current_stock, product_names


def generate_report(target_date, previous_stock, current_stock, product_names):
    """
    Generate and print inventory report.
    
    Args:
        target_date (datetime): Target date
        previous_stock (dict): Stock at start of day
        current_stock (dict): Stock at end of day
        product_names (dict): Product ID to name mapping
    """
    if not previous_stock:
        print("No data available for the given date.")
        return

    print("\n" + "="*90)
    print(f"Inventory Stock Report for: {target_date.strftime('%Y-%m-%d')}")
    print("="*90)
    print(f"{'Product ID':<15} {'Product Name':<45} {'Previous Stock':>15} {'Current Stock':>15}")
    print("-"*90)

    # Sort products for consistent output
    for pid in sorted(previous_stock.keys()):
        name = product_names.get(pid, "Unknown")
        prev_stock = previous_stock[pid]
        curr_stock = current_stock[pid]
        print(f"{pid:<15} {name:<45} {prev_stock:>15} {curr_stock:>15}")
    
    print("="*90)


def main():
    """Main function to run inventory simulation."""
    print("--- Inventory Stock Simulation ---")
    
    # Load data
    transactions = load_and_preprocess_data(CSV_FILE_PATH)
    if transactions.empty:
        return

    # Get target date from user
    while True:
        try:
            date_input = input("Enter target date (YYYY-MM-DD): ")
            target_date = datetime.strptime(date_input, "%Y-%m-%d")
            break
        except ValueError:
            print("Invalid format. Please use YYYY-MM-DD.")

    # Run simulation
    prev_stock, curr_stock, names = simulate_inventory(transactions, target_date, MAX_STOCK)

    # Generate report
    generate_report(target_date, prev_stock, curr_stock, names)
if __name__ == "__main__":
    main()
# Out:
# --- Inventory Stock Simulation ---
#
# ==========================================================================================
# Inventory Stock Report for: 2025-03-28
# ==========================================================================================
# Product ID      Product Name                                   Previous Stock   Current Stock
# ------------------------------------------------------------------------------------------
# PVSL0101011125  Basmati Rice (Daawat)                                    -368            -382
# PVSL0101021125  Basmati Rice (India Gate)                                -570            -640
# PVSL0101031125  Basmati Rice (Kohinoor)                                  -443            -473
# PVSL0101041125  Basmati Rice (Tilda)                                     -385            -402
# PVSL0101051125  Basmati Rice (Fortune)                                   -396            -410
# PVSL0102010126  Sona Masoori Rice (Sri Lalitha)                          -444            -464
# PVSL0102020126  Sona Masoori Rice (Pride of India)                       -367            -393
# PVSL0102030126  Sona Masoori Rice (Fortune)                              -458            -492
# PVSL0102040126  Sona Masoori Rice (India Gate)                           -524            -531
# PVSL0102050126  Sona Masoori Rice (Tata Sampann)                         -404            -412
# PVSL0103011025  Kolam Rice (India Gate)                                   -23             -23
# PVSL0103021025  Kolam Rice (Laxmi)                                        -60             -60
# PVSL0103031025  Kolam Rice (Fortune)                                        3               3
# PVSL0103041025  Kolam Rice (Tata Sampann)                                 -12             -16
# PVSL0103051025  Kolam Rice (Sri Sri Tattva)                               -26             -26
# PVSL0104010126  Brown Rice (Daawat)                                       -41             -58
# PVSL0104020126  Brown Rice (India Gate)                                    -1             -18
# PVSL0104030126  Brown Rice (24 Mantra)                                     15              15
# PVSL0104040126  Brown Rice (Organic Tattva)                                 3               0
# PVSL0104050126  Brown Rice (Natureland)                                   -57             -57
# PVSL0105011025  Matta Rice (Double Horse)                                  33              33
# PVSL0105021025  Matta Rice (Nirapara)                                     -12             -28
# PVSL0105031025  Matta Rice (Eastern)                                      -12             -12
# PVSL0105041025  Matta Rice (Bharat Rice)                                  -28             -30
# PVSL0105051025  Matta Rice (Pavizham)                                      -4              -4
# PVSL0106010126  Wheat Flour (Aashirvaad)                                  -42             -42
# PVSL0106020126  Wheat Flour (Pillsbury)                                    19               7
# PVSL0106030126  Wheat Flour (Naturefresh)                                 -34             -35
# PVSL0106040126  Wheat Flour (Patanjali)                                   -16             -24
# PVSL0106050126  Wheat Flour (ITC)                                         -19             -27
# PVSL0107011025  Maida (Pillsbury)                                         -57             -65
# PVSL0107021025  Maida (Aashirvaad)                                          5              -2
# PVSL0107031025  Maida (Naturefresh)                                        21              15
# PVSL0107041025  Maida (Fortune)                                           -18             -18
# PVSL0107051025  Maida (Golden Harvest)                                     -5              -5
# PVSL0108011025  Multigrain Flour (Aashirvaad)                              -3              -3
# PVSL0108021025  Multigrain Flour (Patanjali)                              -53             -60
# PVSL0108031025  Multigrain Flour (Pillsbury)                              -75             -84
# PVSL0108041025  Multigrain Flour (24 Mantra)                              -15             -26
# PVSL0108051025  Multigrain Flour (Naturefresh)                              9              -7
# PVSL0109010126  Pulses (24 Mantra)                                        -17             -17
# PVSL0109020126  Pulses (Tata Sampann)                                     -28             -36
# PVSL0109030126  Pulses (PS)                                                12              12
# PVSL0109040126  Pulses (Uttam)                                             23              23
# PVSL0109050126  Pulses (Fortune)                                           -7             -12
# PVSL0110010126  Lentils (Tata Sampann)                                    -20             -20
# PVSL0110020126  Lentils (24 Mantra)                                       -83             -88
# PVSL0110030126  Lentils (Fortune)                                         -22             -29
# PVSL0110040126  Lentils (Organic Tattva)                                   -8             -23
# PVSL0110050126  Lentils (Vedaka)                                          -10             -12
# PVSL0111011025  Spices (MDH)                                              -41             -51
# PVSL0111021025  Spices (Everest)                                           34              26
# PVSL0111031025  Spices (Catch)                                              8               8
# PVSL0111041025  Spices (Badshah)                                           -7             -12
# PVSL0111051025  Spices (Patanjali)                                         19              10
# PVSL0111061025  Spices (Aashirvaad)                                       -16             -26
# PVSL0112010925  Masalas (Everest)                                         -21             -35
# PVSL0112020925  Masalas (MDH)                                             -34             -34
# PVSL0112030925  Masalas (Catch)                                           -44             -52
# PVSL0112040925  Masalas (Patanjali)                                       -37             -45
# PVSL0112050925  Masalas (Aachi)                                           -12             -12
# PVSL0112060925  Masalas (Badshah)                                          24              24
# PVSL0113011125  Milk (Amul)                                               -62             -71
# PVSL0113021125  Milk (Mother Dairy)                                       -21             -39
# PVSL0113031125  Milk (Jersey)                                             -61             -69
# PVSL0113041125  Milk (Gopaljee)                                             1               1
# PVSL0113051125  Milk (Hatsun)                                             -32             -38
# PVSL0113061125  Milk (Heritage)                                            19               0
# PVSL0114011125  Curd (Amul)                                                14              14
# PVSL0114021125  Curd (Mother Dairy)                                        18               8
# PVSL0114031125  Curd (Jersey)                                              38              34
# PVSL0114041125  Curd (Milky Mist)                                         -13             -31
# PVSL0114051125  Curd (Gowardhan)                                           15              13
# PVSL0114061125  Curd (Heritage)                                             6              -3
# PVSL0115011125  Paneer (Amul)                                             -24             -24
# PVSL0115021125  Paneer (Mother Dairy)                                     -13             -13
# PVSL0115031125  Paneer (Gowardhan)                                         10               7
# PVSL0115041125  Paneer (Milky Mist)                                       -23             -23
# PVSL0115051125  Paneer (Nandini)                                          -65             -65
# PVSL0115061125  Paneer (Heritage)                                         -10             -26
# PVSL0116011125  Sunflower Oil (Fortune)                                    -8              -8
# PVSL0116021125  Sunflower Oil (Saffola)                                     1              -7
# PVSL0116031125  Sunflower Oil (Dhara)                                      13               8
# PVSL0116041125  Sunflower Oil (Emami)                                     -29             -31
# PVSL0116051125  Sunflower Oil (Patanjali)                                 -39             -40
# PVSL0117010126  Mustard Oil (Patanjali)                                    10               0
# PVSL0117020126  Mustard Oil (Engine)                                      -24             -32
# PVSL0117030126  Mustard Oil (Fortune)                                     -25             -25
# PVSL0117040126  Mustard Oil (Dhara)                                        -2              -3
# PVSL0117050126  Mustard Oil (Emami)                                       -25             -29
# PVSL0118010126  Groundnut Oil (Fortune)                                   -19             -24
# PVSL0118020126  Groundnut Oil (24 Mantra)                                 -51             -51
# PVSL0118030126  Groundnut Oil (Dhara)                                      28              23
# PVSL0118040126  Groundnut Oil (Natureland)                                -12             -12
# PVSL0118050126  Groundnut Oil (Anveshan)                                  -21             -21
# PVSL0119010925  Soybean Oil (Fortune)                                      44              24
# PVSL0119020925  Soybean Oil (Saffola)                                     -59             -63
# PVSL0119030925  Soybean Oil (Dhara)                                       -13             -16
# PVSL0119040925  Soybean Oil (Gagan)                                       -13             -33
# PVSL0119050925  Soybean Oil (Patanjali)                                    35              34
# PVSL0120010126  Rice Bran Oil (Fortune)                                     5              -1
# PVSL0120020126  Rice Bran Oil (Saffola)                                   -73             -73
# PVSL0120030126  Rice Bran Oil (Riso)                                      -67             -67
# PVSL0120040126  Rice Bran Oil (Emami)                                     -64             -64
# PVSL0120050126  Rice Bran Oil (Patanjali)                                  17               8
# PVSL0121010925  Coconut Oil (Parachute)                                   -11             -17
# PVSL0121020925  Coconut Oil (Maxcare)                                      18              18
# PVSL0121030925  Coconut Oil (KPL Shudhi)                                  -20             -28
# PVSL0121040925  Coconut Oil (Patanjali)                                     7               7
# PVSL0121050925  Coconut Oil (Vedaka)                                       33              33
# PVSL0122011125  Olive Oil (Figaro)                                          1              -2
# PVSL0122021125  Olive Oil (Disano)                                          5               5
# PVSL0122031125  Olive Oil (Borges)                                          8               8
# PVSL0122041125  Olive Oil (Del Monte)                                     -42             -44
# PVSL0122051125  Olive Oil (Oleev)                                         -27             -27
# PVSL0123010925  Chips (Lays)                                              -61             -71
# PVSL0123020925  Chips (Bingo)                                             -15             -25
# PVSL0123030925  Chips (Balaji)                                              5               5
# PVSL0123040925  Chips (Uncle Chipps)                                       10               9
# PVSL0123050925  Chips (Too Yumm)                                           18              18
# PVSL0124010925  Namkeens (Haldiram's)                                      -2             -10
# PVSL0124020925  Namkeens (Bikano)                                         -41             -43
# PVSL0124030925  Namkeens (Bikanervala)                                    -38             -38
# PVSL0124040925  Namkeens (Balaji)                                         -43             -49
# PVSL0124050925  Namkeens (Kurkure)                                         14               7
# PVSL0125011125  Snacks (Haldiram's)                                        -3              -3
# PVSL0125021125  Snacks (Parle)                                            -36             -36
# PVSL0125031125  Snacks (Bikano)                                            17              10
# PVSL0125041125  Snacks (Too Yumm)                                         -48             -57
# PVSL0125051125  Snacks (Kurkure)                                          -23             -23
# PVSL0125061125  Snacks (Balaji)                                            29              29
# PVSL0126011025  Biscuits (Britannia)                                       36              30
# PVSL0126021025  Biscuits (Parle)                                          -42             -42
# PVSL0126031025  Biscuits (Sunfeast)                                       -20             -25
# PVSL0126041025  Biscuits (Unibic)                                          10              10
# PVSL0126051025  Biscuits (Cremica)                                        -49             -55
# PVSL0126061025  Biscuits (Anmol)                                           -7              -7
# PVSL0126071025  Biscuits (Priya Gold)                                      35              35
# PVSL0127011025  Chocolates (Amul)                                         -51             -61
# PVSL0127021025  Chocolates (Cadbury)                                      -12             -12
# PVSL0127031025  Chocolates (Nestlé)                                        20              15
# PVSL0127041025  Chocolates (Ferrero)                                       -2              -7
# PVSL0127051025  Chocolates (Campco)                                        -6              -9
# PVSL0127061025  Chocolates (Hershey's India)                              -25             -34
# PVSL0127071025  Chocolates (Lotus)                                        -13             -13
# PVSL0128011225  Tea (Tata Tea)                                            -34             -38
# PVSL0128021225  Tea (Brooke Bond)                                          -4              -4
# PVSL0128031225  Tea (Girnar)                                               22              22
# PVSL0128041225  Tea (Society Tea)                                          11              11
# PVSL0128051225  Tea (Wagh Bakri)                                          -27             -30
# PVSL0129011025  Coffee (Bru)                                                9               0
# PVSL0129021025  Coffee (Coffee Day)                                       -41             -44
# PVSL0129031025  Coffee (Nescafé)                                           20              12
# PVSL0129041025  Coffee (Continental)                                       12              12
# PVSL0129051025  Coffee (Tata Coffee)                                      -35             -36
# PVSL0130011025  Ready-to-Cook (MTR)                                        41              37
# PVSL0130021025  Ready-to-Cook (ITC Kitchens of India)                      17              13
# PVSL0130031025  Ready-to-Cook (Gits)                                      -15             -15
# PVSL0130041025  Ready-to-Cook (Haldiram's)                                 21              14
# PVSL0130051025  Ready-to-Cook (Kellogg's)                                 -60             -62
# PVSL0131011025  Ready-to-Eat (MTR)                                         26              24
# PVSL0131021025  Ready-to-Eat (ITC Kitchens of India)                       11               5
# PVSL0131031025  Ready-to-Eat (Gits)                                       -35             -35
# PVSL0131041025  Ready-to-Eat (Haldiram's)                                 -10             -10
# PVSL0131051025  Ready-to-Eat (Kellogg's)                                  -29             -29
# PVSL0132010126  Frozen Paratha (ITC Master Chef)                          -17             -21
# PVSL0132020126  Frozen Paratha (Amul)                                     -59             -59
# PVSL0132030126  Frozen Paratha (McCain)                                    -8             -13
# PVSL0132040126  Frozen Paratha (Haldiram's)                               -36             -39
# PVSL0132050126  Frozen Paratha (Vadilal)                                   -9              -9
# PVSL0133011025  Frozen French Fries (McCain)                              -17             -18
# PVSL0133021025  Frozen French Fries (ITC Master Chef)                      35              35
# PVSL0133031025  Frozen French Fries (Godrej Yummiez)                      -74             -87
# PVSL0133041025  Frozen French Fries (Vadilal)                              -1              -1
# PVSL0134011125  Frozen Vegetables Mix (Safal)                              14               9
# PVSL0134021125  Frozen Vegetables Mix (Vadilal)                            30              25
# PVSL0134031125  Frozen Vegetables Mix (Godrej Yummiez)                    -14             -14
# PVSL0134041125  Frozen Vegetables Mix (Mother Dairy)                      -65             -65
# PVSL0135010925  Frozen Samosa (Haldiram's)                                 43              38
# PVSL0135020925  Frozen Samosa (ITC Master Chef)                           -48             -52
# PVSL0135030925  Frozen Samosa (McCain)                                    -32             -40
# PVSL0135040925  Frozen Samosa (Vadilal)                                   -17             -19
# PVSL0136010925  Frozen Paneer Tikka (ITC Master Chef)                      27              25
# PVSL0136020925  Frozen Paneer Tikka (Godrej Yummiez)                      -40             -50
# PVSL0136030925  Frozen Paneer Tikka (Vadilal)                             -30             -42
# PVSL0136040925  Frozen Paneer Tikka (Amul)                                -17             -17
# PVSL0137011225  Frozen Nuggets (Godrej Yummiez)                           -50             -76
# PVSL0137021225  Frozen Nuggets (ITC Master Chef)                          -74             -74
# PVSL0137031225  Frozen Nuggets (McCain)                                   -21             -21
# PVSL0137041225  Frozen Nuggets (Venky's)                                   24              24
# PVSL0138011225  Noodles (Maggi)                                             2             -10
# PVSL0138021225  Noodles (Sunfeast Yippee)                                 -23             -23
# PVSL0138031225  Noodles (Top Ramen)                                       -26             -34
# PVSL0138041225  Noodles (Wai Wai)                                         -36             -43
# PVSL0138051225  Noodles (Knorr)                                           -53             -67
# PVSL0138061225  Noodles (Patanjali)                                       -26             -26
# PVSL0139010126  Semiya (Vermicelli) (MTR)                                 -14             -29
# PVSL0139020126  Semiya (Vermicelli) (Bambino)                             -27             -29
# PVSL0139030126  Semiya (Vermicelli) (Aachi)                               -47             -47
# PVSL0139040126  Semiya (Vermicelli) (Anil)                                 -4              -4
# PVSL0139050126  Semiya (Vermicelli) (Double Horse)                         10              10
# PVSL0140010925  Pasta (Weikfield)                                          13              12
# PVSL0140020925  Pasta (Disano)                                            -36             -40
# PVSL0140030925  Pasta (Bambino)                                           -13             -16
# PVSL0140040925  Pasta (Del Monte)                                         -27             -32
# PVSL0140050925  Pasta (Sunfeast)                                           10              10
# PVSL0140060925  Pasta (Barilla)                                            10               2
# PVSL0141011125  Spreads (Nutella)                                         -19             -19
# PVSL0141021125  Spreads (Pintola)                                           2              -5
# PVSL0141031125  Spreads (Dr. Oetker)                                        2              -9
# PVSL0141041125  Spreads (Amul)                                             27              20
# PVSL0141051125  Spreads (Alpino)                                            5              -6
# PVSL0141061125  Spreads (Veeba)                                            53              44
# PVSL0142010126  Sauces (Kissan)                                            26              18
# PVSL0142020126  Sauces (Del Monte)                                        -36             -54
# PVSL0142030126  Sauces (Veeba)                                              4               4
# PVSL0142040126  Sauces (Dr. Oetker)                                        10              10
# PVSL0142050126  Sauces (FunFoods)                                         -36             -45
# PVSL0142060126  Sauces (Maggi)                                             -7             -17
# PVSL0201011025  T-Shirt (Peter England)                                     1               1
# PVSL0201021025  T-Shirt (Allen Solly)                                     -13             -13
# PVSL0201031025  T-Shirt (Louis Philippe)                                    7             -14
# PVSL0201041025  T-Shirt (Roadster)                                         20              20
# PVSL0201051025  T-Shirt (UCB)                                             -44             -54
# PVSL0201061025  T-Shirt (John Players)                                     39              37
# PVSL0202011125  Shirts (Louis Philippe)                                    -1              -9
# PVSL0202021125  Shirts (Peter England)                                      1             -13
# PVSL0202031125  Shirts (Raymond)                                           -3              -3
# PVSL0202041125  Shirts (Van Heusen)                                         3              -9
# PVSL0202051125  Shirts (Allen Solly)                                      -48             -53
# PVSL0202061125  Shirts (UCB)                                              -38             -45
# PVSL0203010126  Jeans (Levi's)                                            -34             -34
# PVSL0203020126  Jeans (Wrangler)                                          -51             -51
# PVSL0203030126  Jeans (Spykar)                                            -19             -26
# PVSL0203040126  Jeans (Lee)                                               -35             -45
# PVSL0203050126  Jeans (Flying Machine)                                    -13             -18
# PVSL0203060126  Jeans (Pepe Jeans)                                          0              -7
# PVSL0204011225  Dresses (Biba)                                            -12             -16
# PVSL0204021225  Dresses (W for Woman)                                       4              -5
# PVSL0204031225  Dresses (Global Desi)                                     -39             -39
# PVSL0204041225  Dresses (AND)                                             -11             -20
# PVSL0204051225  Dresses (FabIndia)                                        -52             -52
# PVSL0204061225  Dresses (Zara)                                            -41             -41
# PVSL0205011125  Salwar Suits (Biba)                                        25              22
# PVSL0205021125  Salwar Suits (W for Woman)                                -26             -26
# PVSL0205031125  Salwar Suits (Aurelia)                                     14               6
# PVSL0205041125  Salwar Suits (Global Desi)                                -40             -46
# PVSL0205051125  Salwar Suits (FabIndia)                                    16              16
# PVSL0205061125  Salwar Suits (Libas)                                        8               8
# PVSL0206011225  Ethnic Wear (Manyavar)                                    -23             -23
# PVSL0206021225  Ethnic Wear (Mohey)                                        11              11
# PVSL0206031225  Ethnic Wear (FabIndia)                                     -6              -6
# PVSL0206041225  Ethnic Wear (Biba)                                         -4             -14
# PVSL0206051225  Ethnic Wear (W for Woman)                                 -43             -53
# PVSL0206061225  Ethnic Wear (Global Desi)                                  16               9
# PVSL0207011125  Kurtas (FabIndia)                                         -20             -20
# PVSL0207021125  Kurtas (Manyavar)                                         -36             -36
# PVSL0207031125  Kurtas (Aurelia)                                           13              -3
# PVSL0207041125  Kurtas (Libas)                                             -9              -9
# PVSL0207051125  Kurtas (Indya)                                            -17             -23
# PVSL0207061125  Kurtas (Soch)                                             -13             -13
# PVSL0208011025  Leggings (Lyra)                                           -27             -41
# PVSL0208021025  Leggings (Jockey)                                         -23             -23
# PVSL0208031025  Leggings (Rupa)                                           -22             -22
# PVSL0208041025  Leggings (Zivame)                                           4               4
# PVSL0208051025  Leggings (Biba)                                           -12             -19
# PVSL0208061025  Leggings (Aurelia)                                        -17             -17
# PVSL0209011225  Track Pants (Jockey)                                      -30             -30
# PVSL0209021225  Track Pants (Puma)                                         24              16
# PVSL0209031225  Track Pants (Nike)                                        -30             -30
# PVSL0209041225  Track Pants (HRX)                                         -27             -46
# PVSL0209051225  Track Pants (Adidas)                                      -33             -33
# PVSL0209061225  Track Pants (Sparx)                                         8               8
# PVSL0210011125  Joggers (Roadster)                                        -22             -22
# PVSL0210021125  Joggers (HRX)                                             -18             -18
# PVSL0210031125  Joggers (Bewakoof)                                        -38             -38
# PVSL0210041125  Joggers (Adidas)                                          -57             -60
# PVSL0210051125  Joggers (Nike)                                            -26             -44
# PVSL0210061125  Joggers (Levi's)                                          -21             -30
# PVSL0211011025  Shorts (HRX)                                              -44             -45
# PVSL0211021025  Shorts (Nike)                                             -50             -50
# PVSL0211031025  Shorts (Jockey)                                            -2              -4
# PVSL0211041025  Shorts (Bewakoof)                                          22              17
# PVSL0211051025  Shorts (Roadster)                                          -1             -10
# PVSL0211061025  Shorts (UCB)                                              -10             -10
# PVSL0212010126  Hoodies (Puma)                                            -29             -29
# PVSL0212020126  Hoodies (Adidas)                                            0              -3
# PVSL0212030126  Hoodies (HRX)                                              20              20
# PVSL0212040126  Hoodies (Roadster)                                        -24             -38
# PVSL0212050126  Hoodies (Nike)                                              4              -1
# PVSL0212060126  Hoodies (H&M)                                             -38             -46
# PVSL0213011225  Blazers (Van Heusen)                                      -14             -14
# PVSL0213021225  Blazers (Peter England)                                   -42             -55
# PVSL0213031225  Blazers (Raymond)                                         -30             -30
# PVSL0213041225  Blazers (Louis Philippe)                                  -37             -52
# PVSL0213051225  Blazers (Allen Solly)                                      -9              -9
# PVSL0213061225  Blazers (Zara)                                             -6              -6
# PVSL0214011125  Formal Trousers (Raymond)                                 -31             -40
# PVSL0214021125  Formal Trousers (Van Heusen)                              -38             -38
# PVSL0214031125  Formal Trousers (Peter England)                           -46             -55
# PVSL0214041125  Formal Trousers (Louis Philippe)                           -4              -5
# PVSL0214051125  Formal Trousers (Blackberrys)                             -26             -36
# PVSL0214061125  Formal Trousers (Allen Solly)                              -6              -6
# PVSL0215010126  Sarees (Suta)                                             -49             -54
# PVSL0215020126  Sarees (FabIndia)                                         -12             -12
# PVSL0215030126  Sarees (Bunkar)                                            11               5
# PVSL0215040126  Sarees (Kalpana)                                            4              -5
# PVSL0215050126  Sarees (Nalli)                                            -20             -29
# PVSL0215060126  Sarees (Varkala Silk)                                      12               9
# PVSL0216010126  Lehengas (Manyavar)                                       -10             -21
# PVSL0216020126  Lehengas (Mohey)                                            9               3
# PVSL0216030126  Lehengas (Biba)                                           -84             -90
# PVSL0216040126  Lehengas (W for Woman)                                     -4             -11
# PVSL0216050126  Lehengas (Koskii)                                          -3              -8
# PVSL0216060126  Lehengas (Libas)                                          -13             -13
# PVSL0217011225  Jackets (Puma)                                             13              13
# PVSL0217021225  Jackets (Nike)                                             32              24
# PVSL0217031225  Jackets (Roadster)                                         -2              -2
# PVSL0217041225  Jackets (H&M)                                             -55             -55
# PVSL0217051225  Jackets (Zara)                                             29              29
# PVSL0217061225  Jackets (UCB)                                              39              31
# PVSL0218011125  Skirts (Zara)                                               3             -25
# PVSL0218021125  Skirts (AND)                                               -8             -22
# PVSL0218031125  Skirts (FabIndia)                                         -14             -22
# PVSL0218041125  Skirts (UCB)                                              -11             -19
# PVSL0218051125  Skirts (Global Desi)                                      -18             -28
# PVSL0218061125  Skirts (Forever 21)                                       -51             -55
# PVSL0219011225  Jumpsuits (AND)                                             7              -1
# PVSL0219021225  Jumpsuits (Global Desi)                                    10              10
# PVSL0219031225  Jumpsuits (Only)                                           -7              -8
# PVSL0219041225  Jumpsuits (Forever 21)                                      5              -3
# PVSL0219051225  Jumpsuits (Mango)                                         -16             -19
# PVSL0219061225  Jumpsuits (Zara)                                          -40             -40
# PVSL0220011025  Nightwear (Jockey)                                        -11             -11
# PVSL0220021025  Nightwear (Clovia)                                         29              19
# PVSL0220031025  Nightwear (Zivame)                                          3               3
# PVSL0220041025  Nightwear (Van Heusen)                                    -19             -27
# PVSL0220051025  Nightwear (Bummer)                                         57              47
# PVSL0220061025  Nightwear (Enamor)                                          5             -12
# PVSL0301010925  Cricket Bat (SG)                                           -2             -13
# PVSL0301020925  Cricket Bat (SS)                                           11               3
# PVSL0301030925  Cricket Bat (MRF)                                         -23             -23
# PVSL0301040925  Cricket Bat (Kookaburra)                                  -17             -23
# PVSL0301050925  Cricket Bat (CEAT)                                          3               3
# PVSL0301060925  Cricket Bat (New Balance)                                   0              -4
# PVSL0302011125  Football (Nivia)                                           -8             -16
# PVSL0302021125  Football (Adidas)                                         -10             -13
# PVSL0302031125  Football (Nike)                                           -47             -56
# PVSL0302041125  Football (Puma)                                            10               3
# PVSL0302051125  Football (Select)                                         -17             -26
# PVSL0302061125  Football (Vector X)                                       -24             -28
# PVSL0303011125  Board Game (Funskool)                                     -57             -66
# PVSL0303021125  Board Game (Hasbro)                                       -37             -46
# PVSL0303031125  Board Game (Mattel)                                        21              16
# PVSL0303041125  Board Game (WinGo)                                        -15             -22
# PVSL0303051125  Board Game (Frank)                                        -38             -38
# PVSL0303061125  Board Game (Smartivity)                                    19              10
# PVSL0304011025  Cycle (Hero)                                               17               1
# PVSL0304021025  Cycle (Atlas)                                             -19             -19
# PVSL0304031025  Cycle (Firefox)                                           -18             -29
# PVSL0304041025  Cycle (Montra)                                            -28             -28
# PVSL0304051025  Cycle (Hercules)                                            4              -5
# PVSL0304061025  Cycle (Ninety One)                                         -5              -7
# PVSL0305010925  Yoga Mat (Decathlon)                                      -14             -29
# PVSL0305020925  Yoga Mat (HRX)                                              7               7
# PVSL0305030925  Yoga Mat (Reebok)                                          36              35
# PVSL0305040925  Yoga Mat (Nike)                                           -15             -24
# PVSL0305050925  Yoga Mat (Cultsport)                                       35              35
# PVSL0305060925  Yoga Mat (Boldfit)                                          7               7
# PVSL0306011025  Swim Suits (Decathlon)                                     -9              -9
# PVSL0306021025  Swim Suits (Speedo)                                       -20             -20
# PVSL0306031025  Swim Suits (Arena)                                        -18             -25
# PVSL0306041025  Swim Suits (HRX)                                          -17             -24
# PVSL0306051025  Swim Suits (Nivia)                                         14               5
# PVSL0306061025  Swim Suits (Zivame)                                        13               9
# PVSL0307011225  Skating Shoes (Nivia)                                     -28             -28
# PVSL0307021225  Skating Shoes (Decathlon)                                  16              11
# PVSL0307031225  Skating Shoes (Strauss)                                    -3              -5
# PVSL0307041225  Skating Shoes (KRF)                                       -73             -77
# PVSL0307051225  Skating Shoes (Jaspo)                                     -16             -24
# PVSL0307061225  Skating Shoes (Cosco)                                       8              -9
# PVSL0308010925  Hot Wheels (Hot Wheels)                                   -33             -33
# PVSL0308020925  Hot Wheels (Maisto)                                       -25             -38
# PVSL0308030925  Hot Wheels (Mattel)                                        15              10
# PVSL0308040925  Hot Wheels (Majorette)                                    -39             -48
# PVSL0308050925  Hot Wheels (Toyzone)                                      -28             -37
# PVSL0308060925  Hot Wheels (Speedage)                                     -19             -19
# PVSL0309011125  Nerf Guns (Nerf)                                            7               0
# PVSL0309021125  Nerf Guns (BoomCo)                                        -40             -49
# PVSL0309031125  Nerf Guns (X-Shot)                                         25              16
# PVSL0309041125  Nerf Guns (Adventure Force)                                 6              -3
# PVSL0309051125  Nerf Guns (Buzz Bee)                                      -39             -39
# PVSL0309061125  Nerf Guns (Hasbro)                                         18              12
# PVSL0310010126  Badminton Racket (Yonex)                                   13               6
# PVSL0310020126  Badminton Racket (Li-Ning)                                -16             -16
# PVSL0310030126  Badminton Racket (Cosco)                                  -47             -47
# PVSL0310040126  Badminton Racket (Nivia)                                  -74             -89
# PVSL0310050126  Badminton Racket (Silver's)                                 0             -10
# PVSL0310060126  Badminton Racket (Victor)                                 -35             -35
# PVSL0311011025  Cricket Ball (SG)                                         -14             -14
# PVSL0311021025  Cricket Ball (SS)                                         -67             -70
# PVSL0311031025  Cricket Ball (Kookaburra)                                  -6             -16
# PVSL0311041025  Cricket Ball (DSC)                                        -24             -35
# PVSL0311051025  Cricket Ball (GM)                                           9               4
# PVSL0311061025  Cricket Ball (BDM)                                        -22             -22
# PVSL0312010126  Basketball (Cosco)                                         -4             -11
# PVSL0312020126  Basketball (Nivia)                                         32              30
# PVSL0312030126  Basketball (Spalding)                                     -66             -75
# PVSL0312040126  Basketball (Adidas)                                        13               5
# PVSL0312050126  Basketball (Nike)                                         -24             -33
# PVSL0312060126  Basketball (Puma)                                         -43             -48
# PVSL0313011025  Tennis Racket (Wilson)                                    -36             -36
# PVSL0313021025  Tennis Racket (Yonex)                                      44              44
# PVSL0313031025  Tennis Racket (Head)                                      -10             -12
# PVSL0313041025  Tennis Racket (Babolat)                                    21              21
# PVSL0313051025  Tennis Racket (Tecnifibre)                                -71             -77
# PVSL0313061025  Tennis Racket (Decathlon)                                 -23             -30
# PVSL0314010925  Dart Board (Strauss)                                      -25             -37
# PVSL0314020925  Dart Board (Aurion)                                       -13             -23
# PVSL0314030925  Dart Board (Winmau)                                       -40             -48
# PVSL0314040925  Dart Board (Toyshine)                                     -42             -57
# PVSL0314050925  Dart Board (Shot)                                          27              27
# PVSL0314060925  Dart Board (Harrows)                                        5               1
# PVSL0315011025  Skipping Rope (Boldfit)                                    -4              -5
# PVSL0315021025  Skipping Rope (Strauss)                                     0              -6
# PVSL0315031025  Skipping Rope (Nivia)                                       1             -11
# PVSL0315041025  Skipping Rope (Cosco)                                     -40             -46
# PVSL0315051025  Skipping Rope (HRX)                                        11              -2
# PVSL0315061025  Skipping Rope (Decathlon)                                 -44             -47
# PVSL0316010925  Toy Car Remote (Toyshine)                                  39              39
# PVSL0316020925  Toy Car Remote (RemoteX)                                  -31             -33
# PVSL0316030925  Toy Car Remote (Maisto)                                     0              -1
# PVSL0316040925  Toy Car Remote (Speedage)                                   0               0
# PVSL0316050925  Toy Car Remote (R/C Zone)                                 -43             -50
# PVSL0316060925  Toy Car Remote (Hikoki)                                    -1              -1
# PVSL0317011125  Action Figures (Hasbro)                                    -1              -1
# PVSL0317021125  Action Figures (Marvel)                                   -24             -34
# PVSL0317031125  Action Figures (Funskool)                                 -18             -40
# PVSL0317041125  Action Figures (Toyshine)                                 -26             -26
# PVSL0317051125  Action Figures (DC)                                       -49             -49
# PVSL0317061125  Action Figures (Transformers)                               4               4
# PVSL0318010126  Doll Set (Barbie)                                           2               2
# PVSL0318020126  Doll Set (Funskool)                                       -16             -16
# PVSL0318030126  Doll Set (Toyshine)                                        16              16
# PVSL0318040126  Doll Set (Mattel)                                          -8             -11
# PVSL0318050126  Doll Set (Chicco)                                          28              23
# PVSL0318060126  Doll Set (Zephyr)                                         -19             -28
# PVSL0319011225  Tricycle (R for Rabbit)                                     4               4
# PVSL0319021225  Tricycle (LuvLap)                                         -26             -38
# PVSL0319031225  Tricycle (Amardeep)                                      -106            -116
# PVSL0319041225  Tricycle (Baybee)                                          27               3
# PVSL0319051225  Tricycle (Dash)                                            48              44
# PVSL0319061225  Tricycle (Toyhouse)                                       -34             -34
# PVSL0320011225  Scooter (Kick) (R for Rabbit)                             -32             -49
# PVSL0320021225  Scooter (Kick) (Strauss)                                   49              45
# PVSL0320031225  Scooter (Kick) (Toyshine)                                  -9              -9
# PVSL0320041225  Scooter (Kick) (Aurion)                                    15               6
# PVSL0320051225  Scooter (Kick) (NHR)                                       17              17
# PVSL0320061225  Scooter (Kick) (Zyklo)                                    -35             -35
# PVSL0401010925  Headphones (boAt)                                         -43             -43
# PVSL0401020925  Headphones (JBL)                                           31              27
# PVSL0401030925  Headphones (Sony)                                          19              11
# PVSL0401040925  Headphones (Noise)                                        -38             -48
# PVSL0401050925  Headphones (Sennheiser)                                    -2              -8
# PVSL0401060925  Headphones (Realme)                                        21              21
# PVSL0402011225  LED TV (Samsung)                                           -4              -4
# PVSL0402021225  LED TV (Sony)                                             -14             -29
# PVSL0402031225  LED TV (LG)                                                27              27
# PVSL0402041225  LED TV (Panasonic)                                         -1              -1
# PVSL0402051225  LED TV (TCL)                                               30              30
# PVSL0402061225  LED TV (Mi)                                                 8               8
# PVSL0403010126  Mixer Grinder (Philips)                                    -5              -8
# PVSL0403020126  Mixer Grinder (Preethi)                                    46              37
# PVSL0403030126  Mixer Grinder (Bajaj)                                     -50             -50
# PVSL0403040126  Mixer Grinder (Sujata)                                     -6             -16
# PVSL0403050126  Mixer Grinder (Panasonic)                                 -47             -47
# PVSL0403060126  Mixer Grinder (Havells)                                    12              12
# PVSL0404011225  Refrigerator (Samsung)                                    -24             -24
# PVSL0404021225  Refrigerator (LG)                                         -34             -36
# PVSL0404031225  Refrigerator (Whirlpool)                                  -22             -28
# PVSL0404041225  Refrigerator (Haier)                                      -51             -51
# PVSL0404051225  Refrigerator (Godrej)                                      11              10
# PVSL0404061225  Refrigerator (Panasonic)                                  -11             -11
# PVSL0405010126  Microwave (Samsung)                                       -14             -17
# PVSL0405020126  Microwave (IFB)                                           -36             -45
# PVSL0405030126  Microwave (Godrej)                                        -41             -47
# PVSL0405040126  Microwave (LG)                                            -34             -34
# PVSL0405050126  Microwave (Panasonic)                                     -35             -35
# PVSL0405060126  Microwave (Haier)                                         -46             -53
# PVSL0406011125  Beard Trimmer (Philips)                                     3              -5
# PVSL0406021125  Beard Trimmer (Syska)                                     -49             -49
# PVSL0406031125  Beard Trimmer (Mi)                                        -39             -50
# PVSL0406041125  Beard Trimmer (Havells)                                   -42             -53
# PVSL0406051125  Beard Trimmer (Nova)                                      -31             -31
# PVSL0406061125  Beard Trimmer (Wahl)                                       -4              -9
# PVSL0407010126  Smartphone (Samsung)                                      -23             -31
# PVSL0407020126  Smartphone (OnePlus)                                      -27             -36
# PVSL0407030126  Smartphone (Xiaomi)                                       -10             -13
# PVSL0407040126  Smartphone (Realme)                                       -38             -38
# PVSL0407050126  Smartphone (Vivo)                                         -40             -52
# PVSL0407060126  Smartphone (Apple)                                          7               7
# PVSL0408010925  Tablet (Samsung)                                          -15             -21
# PVSL0408020925  Tablet (Apple)                                            -42             -42
# PVSL0408030925  Tablet (Lenovo)                                           -56             -64
# PVSL0408040925  Tablet (Xiaomi)                                            33              23
# ...
# PVSL0902040126  Shower Gel (Fiama)                                          2              -6
# PVSL0902041025  Shower Gel (Fiama)                                         19              19
# PVSL0902041125  Shower Gel (Fiama)                                         12               7
# PVSL0902041225  Shower Gel (Fiama)                                        -85             -85
# PVSL0902050126  Shower Gel (The Body Shop)                               -136            -136
# PVSL0902050925  Shower Gel (The Body Shop)                                 25              16
# PVSL0902051025  Shower Gel (The Body Shop)                                -69             -92
# PVSL0902060126  Shower Gel (Himalaya)                                       7               4
# PVSL0902060925  Shower Gel (Himalaya)                                    -114            -128
# PVSL0902061225  Shower Gel (Himalaya)                                    -102            -119
# PVSL0903010126  Soap (Lux)                                                 34              34
# PVSL0903010925  Soap (Lux)                                                 13               3
# PVSL0903011025  Soap (Lux)                                                  2              -2
# PVSL0903011225  Soap (Lux)                                                -97            -133
# PVSL0903020126  Soap (Dove)                                               -15             -22
# PVSL0903020925  Soap (Dove)                                               -40             -46
# PVSL0903021025  Soap (Dove)                                                18              18
# PVSL0903021225  Soap (Dove)                                               -94            -115
# PVSL0903030126  Soap (Pears)                                              -67             -67
# PVSL0903030925  Soap (Pears)                                              -88            -118
# PVSL0903031125  Soap (Pears)                                              -66             -66
# PVSL0903040126  Soap (Dettol)                                               2               2
# PVSL0903040925  Soap (Dettol)                                            -134            -134
# PVSL0903041125  Soap (Dettol)                                              -9             -19
# PVSL0903041225  Soap (Dettol)                                             -28             -28
# PVSL0903050126  Soap (Lifebuoy)                                           -82             -99
# PVSL0903051125  Soap (Lifebuoy)                                            -5             -11
# PVSL0903051225  Soap (Lifebuoy)                                          -152            -152
# PVSL0903060126  Soap (Cinthol)                                           -102            -102
# PVSL0903060925  Soap (Cinthol)                                           -123            -147
# PVSL0903061025  Soap (Cinthol)                                             -8             -20
# PVSL0904010925  Shampoo (Pantene)                                          -5              -9
# PVSL0904011025  Shampoo (Pantene)                                        -122            -132
# PVSL0904011125  Shampoo (Pantene)                                         -53             -62
# PVSL0904011225  Shampoo (Pantene)                                          16               1
# PVSL0904020126  Shampoo (Head & Shoulders)                                -30             -37
# PVSL0904020925  Shampoo (Head & Shoulders)                                 -3              -3
# PVSL0904021225  Shampoo (Head & Shoulders)                               -227            -239
# PVSL0904030925  Shampoo (Dove)                                           -159            -169
# PVSL0904031125  Shampoo (Dove)                                             31              30
# PVSL0904031225  Shampoo (Dove)                                           -151            -162
# PVSL0904040126  Shampoo (Tresemme)                                         11              -4
# PVSL0904041125  Shampoo (Tresemme)                                       -329            -338
# PVSL0904041225  Shampoo (Tresemme)                                        -23             -26
# PVSL0904050126  Shampoo (Sunsilk)                                         -90            -101
# PVSL0904050925  Shampoo (Sunsilk)                                        -175            -181
# PVSL0904051125  Shampoo (Sunsilk)                                          49              45
# PVSL0904060126  Shampoo (Clinic Plus)                                      19              19
# PVSL0904060925  Shampoo (Clinic Plus)                                    -158            -167
# PVSL0904061025  Shampoo (Clinic Plus)                                      33              33
# PVSL0904061125  Shampoo (Clinic Plus)                                       3              -7
# PVSL0905010126  Hair Oil (Parachute)                                     -139            -150
# PVSL0905010925  Hair Oil (Parachute)                                      -27             -33
# PVSL0905011025  Hair Oil (Parachute)                                        7               3
# PVSL0905011125  Hair Oil (Parachute)                                       25              25
# PVSL0905020126  Hair Oil (Dabur)                                         -132            -135
# PVSL0905021025  Hair Oil (Dabur)                                          -46             -46
# PVSL0905021125  Hair Oil (Dabur)                                           49              32
# PVSL0905021225  Hair Oil (Dabur)                                           13              13
# PVSL0905030126  Hair Oil (Indulekha)                                     -169            -179
# PVSL0905031025  Hair Oil (Indulekha)                                     -278            -295
# PVSL0905040925  Hair Oil (Patanjali)                                      -28             -42
# PVSL0905041125  Hair Oil (Patanjali)                                     -110            -110
# PVSL0905041225  Hair Oil (Patanjali)                                     -140            -165
# PVSL0905050925  Hair Oil (Bajaj)                                         -144            -151
# PVSL0905051025  Hair Oil (Bajaj)                                          -29             -30
# PVSL0905051125  Hair Oil (Bajaj)                                            9              -3
# PVSL0905051225  Hair Oil (Bajaj)                                           35              35
# PVSL0905061025  Hair Oil (Emami)                                           20              20
# PVSL0905061125  Hair Oil (Emami)                                          -80             -81
# PVSL0905061225  Hair Oil (Emami)                                          -96            -120
# PVSL0906010126  Face Wash (Himalaya)                                      -27             -27
# PVSL0906010925  Face Wash (Himalaya)                                     -190            -190
# PVSL0906011125  Face Wash (Himalaya)                                     -185            -185
# PVSL0906020126  Face Wash (Clean & Clear)                                -114            -121
# PVSL0906020925  Face Wash (Clean & Clear)                                -119            -132
# PVSL0906021125  Face Wash (Clean & Clear)                                 -24             -31
# PVSL0906030925  Face Wash (Garnier)                                      -130            -130
# PVSL0906031125  Face Wash (Garnier)                                       -42             -42
# PVSL0906031225  Face Wash (Garnier)                                      -124            -146
# PVSL0906040126  Face Wash (Pond's)                                        -51             -55
# PVSL0906040925  Face Wash (Pond's)                                         -7             -12
# PVSL0906041025  Face Wash (Pond's)                                        -73             -73
# PVSL0906041125  Face Wash (Pond's)                                         12               5
# PVSL0906041225  Face Wash (Pond's)                                          2              -6
# PVSL0906050126  Face Wash (Mamaearth)                                      -9             -11
# PVSL0906050925  Face Wash (Mamaearth)                                     -29             -45
# PVSL0906051125  Face Wash (Mamaearth)                                     -55             -70
# PVSL0906051225  Face Wash (Mamaearth)                                      48              48
# PVSL0906060925  Face Wash (Nivea)                                         -17             -27
# PVSL0906061125  Face Wash (Nivea)                                         -16             -16
# PVSL0906061225  Face Wash (Nivea)                                        -259            -281
# PVSL0907010126  Handwash (Dettol)                                          34              34
# PVSL0907010925  Handwash (Dettol)                                           1              -9
# PVSL0907011025  Handwash (Dettol)                                        -155            -155
# PVSL0907011125  Handwash (Dettol)                                         -63             -63
# PVSL0907021025  Handwash (Lifebuoy)                                        15              15
# PVSL0907021125  Handwash (Lifebuoy)                                      -172            -176
# PVSL0907021225  Handwash (Lifebuoy)                                      -179            -194
# PVSL0907030126  Handwash (Savlon)                                           9               8
# PVSL0907031125  Handwash (Savlon)                                        -109            -129
# PVSL0907031225  Handwash (Savlon)                                        -122            -122
# PVSL0907040126  Handwash (Himalaya)                                         5              -5
# PVSL0907040925  Handwash (Himalaya)                                      -118            -138
# PVSL0907041025  Handwash (Himalaya)                                       -26             -26
# PVSL0907041225  Handwash (Himalaya)                                       -65             -84
# PVSL0907050925  Handwash (Palmolive)                                      -16             -38
# PVSL0907051025  Handwash (Palmolive)                                     -103            -111
# PVSL0907051225  Handwash (Palmolive)                                     -148            -160
# PVSL0907060126  Handwash (Godrej)                                           7              -3
# PVSL0907060925  Handwash (Godrej)                                         -37             -39
# PVSL0907061025  Handwash (Godrej)                                        -184            -200
# PVSL0907061125  Handwash (Godrej)                                         -24             -34
# PVSL0908010126  Sanitizer (Dettol)                                       -134            -134
# PVSL0908010925  Sanitizer (Dettol)                                         -3              -3
# PVSL0908011125  Sanitizer (Dettol)                                         24              24
# PVSL0908011225  Sanitizer (Dettol)                                        -23             -32
# PVSL0908020126  Sanitizer (Lifebuoy)                                     -215            -231
# PVSL0908021025  Sanitizer (Lifebuoy)                                      -68             -68
# PVSL0908021225  Sanitizer (Lifebuoy)                                      -42             -47
# PVSL0908030126  Sanitizer (Savlon)                                       -146            -156
# PVSL0908030925  Sanitizer (Savlon)                                       -119            -122
# PVSL0908031025  Sanitizer (Savlon)                                         11               1
# PVSL0908040126  Sanitizer (Himalaya)                                      -20             -20
# PVSL0908040925  Sanitizer (Himalaya)                                      -10             -15
# PVSL0908041025  Sanitizer (Himalaya)                                      -97            -106
# PVSL0908041125  Sanitizer (Himalaya)                                      -35             -35
# PVSL0908050126  Sanitizer (Sterillium)                                    -42             -56
# PVSL0908050925  Sanitizer (Sterillium)                                      7               7
# PVSL0908051025  Sanitizer (Sterillium)                                     32              28
# PVSL0908051125  Sanitizer (Sterillium)                                   -182            -182
# PVSL0908060126  Sanitizer (Purell)                                       -109            -110
# PVSL0908060925  Sanitizer (Purell)                                        -41             -44
# PVSL0908061025  Sanitizer (Purell)                                         23              23
# PVSL0908061225  Sanitizer (Purell)                                         40              34
# PVSL0909011025  Toothpaste (Colgate)                                     -110            -110
# PVSL0909011125  Toothpaste (Colgate)                                      -83             -83
# PVSL0909011225  Toothpaste (Colgate)                                      -11             -11
# PVSL0909020925  Toothpaste (Pepsodent)                                   -109            -116
# PVSL0909021125  Toothpaste (Pepsodent)                                   -258            -271
# PVSL0909031025  Toothpaste (Close-Up)                                    -174            -186
# PVSL0909031125  Toothpaste (Close-Up)                                     -14             -21
# PVSL0909031225  Toothpaste (Close-Up)                                    -106            -112
# PVSL0909040925  Toothpaste (Sensodyne)                                     12              12
# PVSL0909041025  Toothpaste (Sensodyne)                                   -263            -264
# PVSL0909050126  Toothpaste (Patanjali)                                     27              27
# PVSL0909050925  Toothpaste (Patanjali)                                   -158            -166
# PVSL0909051025  Toothpaste (Patanjali)                                    -14             -32
# PVSL0909051225  Toothpaste (Patanjali)                                     22              22
# PVSL0909061025  Toothpaste (Dabur)                                       -183            -183
# PVSL0909061125  Toothpaste (Dabur)                                       -100            -116
# PVSL0910010126  Toothbrush (Colgate)                                      -31             -34
# PVSL0910011025  Toothbrush (Colgate)                                     -306            -320
# PVSL0910011225  Toothbrush (Colgate)                                       32              32
# PVSL0910020925  Toothbrush (Oral-B)                                      -109            -134
# PVSL0910021025  Toothbrush (Oral-B)                                        15               3
# PVSL0910021225  Toothbrush (Oral-B)                                      -164            -164
# PVSL0910030126  Toothbrush (Close-Up)                                    -151            -160
# PVSL0910031025  Toothbrush (Close-Up)                                     -26             -26
# PVSL0910031225  Toothbrush (Close-Up)                                    -148            -162
# PVSL0910040925  Toothbrush (Sensodyne)                                     14              12
# PVSL0910041025  Toothbrush (Sensodyne)                                   -218            -220
# PVSL0910041225  Toothbrush (Sensodyne)                                    -83             -88
# PVSL0910050126  Toothbrush (Trisa)                                        -42             -54
# PVSL0910051125  Toothbrush (Trisa)                                        -90             -94
# PVSL0910051225  Toothbrush (Trisa)                                       -131            -145
# PVSL0910060126  Toothbrush (Ajanta)                                      -136            -150
# PVSL0910060925  Toothbrush (Ajanta)                                         8               8
# PVSL0910061125  Toothbrush (Ajanta)                                       -91            -103
# ==========================================================================================
